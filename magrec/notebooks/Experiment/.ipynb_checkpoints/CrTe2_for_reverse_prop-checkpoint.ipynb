# %%
cd /Users/dub/Magnetisation_reconstruction/magnetisation_reconstruction/Magnetisation
# Out:
# /Users/dub/Magnetisation_reconstruction/magnetisation_reconstruction/Magnetisation

# %%
import numpy as np
import json
import torch
import sys
sys.path.insert(0,'../../magnetisation_reconstruction')

from Magnetisation.Propagator import Propagator
from Magnetisation.Generator import generator_CNN,generator_CNN_J, generator_MLP_bayesian
from Magnetisation.Train import train_cnn,train_J,extract_M_result
from Magnetisation.Evaluate import evaluate
from Magnetisation.Fourier import Fourier

from torch.utils.data import Dataset, TensorDataset
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
from scipy import signal
from scipy import misc
from scipy.ndimage import gaussian_filter
from blitz.modules.base_bayesian_module import BayesianModule
from blitz.utils import variational_estimator

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Extract the data
f = open('../data/CrTe2_for_reverse_prop.json')
data = json.load(f)
MagneticField = np.asarray(data['MagneticFieldImage'])
MagneticField= np.rot90((np.fliplr(MagneticField)))
MagneticField2=MagneticField[10:165,20:170]
# subtract the mean of the magnetic field
fft_signal = np.fft.fft2(MagneticField) 
fft_signal_clean = np.where(fft_signal.imag==0,0,fft_signal)
MagneticField = np.fft.ifft2(fft_signal_clean).real

# Get the Fourier method propagation
unit_conversion = 1e-18 / 9.27e-24
# Define the dictionary for the forward propagation
# PropagationOptions = dict()
# PropagationOptions['PixelSize'] = 5e-08
# PropagationOptions['ImageShape'] = 512
# PropagationOptions['NV'] = dict()
# PropagationOptions['NV']['FindTheta']=False
# PropagationOptions['NV']['Theta'] = 54
# PropagationOptions['NV']['FindPhi']=False
# PropagationOptions['NV']['Phi'] = 90 -90
# PropagationOptions['NV']['Height'] = 6.23e-08
# PropagationOptions['Magnetisation'] = dict()
# PropagationOptions['Magnetisation']['FindTheta']=False
# PropagationOptions['Magnetisation']['Theta'] = 0
# PropagationOptions['Magnetisation']['FindPhi']=False
# PropagationOptions['Magnetisation']['Phi'] = 0
# PropagationOptions['FFT'] = dict()
# PropagationOptions['FFT']['Filter']['useHanning'] = True
# PropagationOptions["FFT"]["PaddingFactor"]= None
# PropagationOptions["FFT"]["performPadding"]= None

# Define the dictionary for the forward propagation
PropagationOptions = dict()
PropagationOptions['PixelSize'] = 38.9e-9
PropagationOptions['ImageShape'] = 256
PropagationOptions['NV'] = dict()
PropagationOptions['NV']['FindTheta']=False
PropagationOptions['NV']['Theta'] = 59
PropagationOptions['NV']['FindPhi']=False
PropagationOptions['NV']['Phi'] = 180
PropagationOptions['NV']['Height'] = 93e-9
PropagationOptions['Magnetisation'] = dict()
PropagationOptions['Magnetisation']['FindTheta']=False
PropagationOptions['Magnetisation']['Theta'] = 90
PropagationOptions['Magnetisation']['FindPhi']=True
PropagationOptions['Magnetisation']['Phi'] = 90
PropagationOptions['FFT'] = dict()
PropagationOptions["FFT"]["PaddingFactor"]= 4
PropagationOptions["FFT"]["performPadding"]= False
PropagationOptions["FFT"]["PaddingMode"] = 'constant'
PropagationOptions['FFT']['Extended'] = False
PropagationOptions['FFT']['Extention'] = 100
PropagationOptions['FFT']['Filter'] = dict()
PropagationOptions['FFT']['Filter']['useHanning'] = True 
PropagationOptions['FFT']['Filter']['useHighCutoff'] = False
PropagationOptions['FFT']['Filter']['useLowCutoff'] = False
PropagationOptions['FFT']['Filter']['LambdaHighCutoff'] = 100e-9
PropagationOptions['FFT']['Filter']['LambdaLowCutoff'] = 7e-06


PROP = Propagator(PropagationOptions, MagneticField,PropagationOptions['ImageShape'])

# Extend the data set to the requested square dimensions
# Returns to self.MagneticFieldExtended
PROP.reshape()

display(PropagationOptions)
# Out:
# {'PixelSize': 3.89e-08,
#  'ImageShape': 256,
#  'NV': {'FindTheta': False,
#   'Theta': 59,
#   'FindPhi': False,
#   'Phi': 180,
#   'Height': 9.3e-08},
#  'Magnetisation': {'FindTheta': False,
#   'Theta': 90,
#   'FindPhi': True,
#   'Phi': 90},
#  'FFT': {'PaddingFactor': 4,
#   'performPadding': False,
#   'PaddingMode': 'constant',
#   'Extended': False,
#   'Extention': 100,
#   'Filter': {'useHanning': True,
#    'useHighCutoff': False,
#    'useLowCutoff': False,
#    'LambdaHighCutoff': 1e-07,
#    'LambdaLowCutoff': 7e-06}}}

# %%
MagneticField4=rotate(MagneticField3,-17)

# %%
MagneticField3=MagneticField2[0:160,20:150]

# %%
MagneticField2=MagneticField[10:165,20:170]

# %%
plt.imshow(MagneticField4, cmap="bwr")
plt.colorbar()

# %%
plt.imshow(MagneticField2, cmap="bwr")
plt.colorbar()

# %%
plt.imshow(MagneticField3, cmap="bwr")
plt.colorbar()

# %%
G_cnn = generator_CNN(Size=1,ImageSize=PropagationOptions['ImageShape'],bayesian=True).to(device)
G_cnn_optimizer = torch.optim.Adam(G_cnn.parameters())

# %%
img_input = torch.FloatTensor((PROP.MagneticFieldExtended)[np.newaxis, np.newaxis, :, :])
mask_t=torch.FloatTensor(PROP.Mask[np.newaxis,np.newaxis])
#img_output = torch.FloatTensor((Magnetization)[np.newaxis,np.newaxis,:,:])
train_data_cnn = TensorDataset(img_input,img_input)
train_loader_cnn = DataLoader( dataset=(train_data_cnn))

# %%
ML_options = dict()
ML_options['mlp']=False
ML_options['size']=PropagationOptions['ImageShape']
ML_options['LossFunction']='L2'
ML_options['Magnetisation']=None
ML_options['IntegerOnly']=False
ML_options['PositiveMagnetisationOnly']=False
ML_options['PrintLossValue']=False
ML_options['Epochs']=100

# %%
from skimage import data
from skimage.transform import rotate

# %%
bnv_cnn=train_cnn(device, G_cnn, G_cnn_optimizer, train_loader_cnn, PROP, ML_options)
# Out:
# L2
#   0%|          | 0/100 [00:00<?, ?it/s]
# integer
# magnetisation_theta
#   1%|          | 1/100 [00:00<00:35,  2.82it/s]
# integer
# magnetisation_theta
#   2%|▏         | 2/100 [00:00<00:41,  2.34it/s]
# integer
# magnetisation_theta
#   3%|▎         | 3/100 [00:01<00:40,  2.39it/s]
# integer
# magnetisation_theta
#   4%|▍         | 4/100 [00:01<00:42,  2.28it/s]
# integer
# magnetisation_theta
#   5%|▌         | 5/100 [00:01<00:36,  2.61it/s]
# integer
# magnetisation_theta
#   6%|▌         | 6/100 [00:02<00:32,  2.87it/s]
# integer
# magnetisation_theta
#   7%|▋         | 7/100 [00:02<00:31,  2.94it/s]
# integer
# magnetisation_theta
#   8%|▊         | 8/100 [00:02<00:30,  3.06it/s]
# integer
# magnetisation_theta
#   9%|▉         | 9/100 [00:03<00:34,  2.67it/s]
# integer
# magnetisation_theta
#  10%|█         | 10/100 [00:03<00:30,  2.94it/s]
# integer
# magnetisation_theta
#  11%|█         | 11/100 [00:04<00:31,  2.84it/s]
# integer
# magnetisation_theta
#  12%|█▏        | 12/100 [00:04<00:29,  3.01it/s]
# integer
# magnetisation_theta
#  13%|█▎        | 13/100 [00:04<00:27,  3.11it/s]
# integer
# magnetisation_theta
#  14%|█▍        | 14/100 [00:04<00:25,  3.36it/s]
# integer
# magnetisation_theta
#  15%|█▌        | 15/100 [00:05<00:25,  3.36it/s]
# integer
# magnetisation_theta
#  16%|█▌        | 16/100 [00:05<00:23,  3.52it/s]
# integer
# magnetisation_theta
#  17%|█▋        | 17/100 [00:05<00:22,  3.63it/s]
# integer
# magnetisation_theta
#  18%|█▊        | 18/100 [00:05<00:22,  3.70it/s]
# integer
# magnetisation_theta
#  19%|█▉        | 19/100 [00:06<00:23,  3.48it/s]
# integer
# magnetisation_theta
#  20%|██        | 20/100 [00:06<00:22,  3.51it/s]
# integer
# magnetisation_theta
#  21%|██        | 21/100 [00:06<00:22,  3.58it/s]
# integer
# magnetisation_theta
#  22%|██▏       | 22/100 [00:07<00:21,  3.70it/s]
# integer
# magnetisation_theta
#  23%|██▎       | 23/100 [00:07<00:19,  3.94it/s]
# integer
# magnetisation_theta
#  24%|██▍       | 24/100 [00:07<00:19,  3.87it/s]
# integer
# magnetisation_theta
#  25%|██▌       | 25/100 [00:07<00:18,  4.06it/s]
# integer
# magnetisation_theta
#  27%|██▋       | 27/100 [00:08<00:16,  4.45it/s]
# integer
# magnetisation_theta
#  28%|██▊       | 28/100 [00:08<00:15,  4.60it/s]
# integer
# magnetisation_theta
# integer
#  29%|██▉       | 29/100 [00:08<00:15,  4.65it/s]
# magnetisation_theta
# integer
#  30%|███       | 30/100 [00:08<00:15,  4.67it/s]
# magnetisation_theta
# integer
#  31%|███       | 31/100 [00:08<00:14,  4.66it/s]
# magnetisation_theta
# integer
#  32%|███▏      | 32/100 [00:09<00:14,  4.68it/s]
# magnetisation_theta
# integer
#  33%|███▎      | 33/100 [00:09<00:14,  4.68it/s]
# magnetisation_theta
# integer
#  34%|███▍      | 34/100 [00:09<00:14,  4.66it/s]
# magnetisation_theta
# integer
#  35%|███▌      | 35/100 [00:09<00:14,  4.47it/s]
# magnetisation_theta
# integer
#  36%|███▌      | 36/100 [00:10<00:13,  4.60it/s]
# magnetisation_theta
# integer
#  37%|███▋      | 37/100 [00:10<00:13,  4.63it/s]
# magnetisation_theta
# integer
#  38%|███▊      | 38/100 [00:10<00:13,  4.63it/s]
# magnetisation_theta
# integer
#  39%|███▉      | 39/100 [00:10<00:13,  4.63it/s]
# magnetisation_theta
# integer
#  40%|████      | 40/100 [00:10<00:12,  4.65it/s]
# magnetisation_theta
# integer
#  41%|████      | 41/100 [00:11<00:12,  4.70it/s]
# magnetisation_theta
# integer
#  42%|████▏     | 42/100 [00:11<00:12,  4.74it/s]
# magnetisation_theta
# integer
#  43%|████▎     | 43/100 [00:11<00:12,  4.72it/s]
# magnetisation_theta
# integer
#  44%|████▍     | 44/100 [00:11<00:11,  4.73it/s]
# magnetisation_theta
# integer
#  45%|████▌     | 45/100 [00:11<00:11,  4.65it/s]
# magnetisation_theta
# integer
#  46%|████▌     | 46/100 [00:12<00:11,  4.57it/s]
# magnetisation_theta
# integer
#  47%|████▋     | 47/100 [00:12<00:11,  4.53it/s]
# magnetisation_theta
# integer
#  48%|████▊     | 48/100 [00:12<00:11,  4.49it/s]
# magnetisation_theta
# integer
#  49%|████▉     | 49/100 [00:12<00:11,  4.57it/s]
# magnetisation_theta
# integer
#  50%|█████     | 50/100 [00:13<00:10,  4.57it/s]
# magnetisation_theta
# integer
#  51%|█████     | 51/100 [00:13<00:10,  4.57it/s]
# magnetisation_theta
# integer
#  52%|█████▏    | 52/100 [00:13<00:10,  4.58it/s]
# magnetisation_theta
# integer
#  53%|█████▎    | 53/100 [00:13<00:09,  4.71it/s]
# magnetisation_theta
# integer
# magnetisation_theta
#  54%|█████▍    | 54/100 [00:13<00:09,  4.78it/s]
# integer
# magnetisation_theta
#  55%|█████▌    | 55/100 [00:14<00:10,  4.30it/s]
# integer
# magnetisation_theta
#  56%|█████▌    | 56/100 [00:14<00:10,  4.28it/s]
# integer
# magnetisation_theta
#  57%|█████▋    | 57/100 [00:14<00:09,  4.33it/s]
# integer
# magnetisation_theta
#  59%|█████▉    | 59/100 [00:15<00:08,  4.62it/s]
# integer
# magnetisation_theta
# integer
# magnetisation_theta
#  60%|██████    | 60/100 [00:15<00:08,  4.66it/s]
# integer
# magnetisation_theta
#  62%|██████▏   | 62/100 [00:15<00:07,  4.82it/s]
# integer
# magnetisation_theta
# integer
#  63%|██████▎   | 63/100 [00:15<00:07,  4.83it/s]
# magnetisation_theta
# integer
#  64%|██████▍   | 64/100 [00:16<00:07,  4.89it/s]
# magnetisation_theta
# integer
# magnetisation_theta
#  66%|██████▌   | 66/100 [00:16<00:06,  4.98it/s]
# integer
# magnetisation_theta
# integer
#  67%|██████▋   | 67/100 [00:16<00:06,  4.94it/s]
# magnetisation_theta
# integer
#  68%|██████▊   | 68/100 [00:16<00:06,  4.85it/s]
# magnetisation_theta
# integer
#  69%|██████▉   | 69/100 [00:17<00:06,  4.70it/s]
# magnetisation_theta
# integer
#  70%|███████   | 70/100 [00:17<00:06,  4.62it/s]
# magnetisation_theta
# integer
#  71%|███████   | 71/100 [00:17<00:06,  4.54it/s]
# magnetisation_theta
# integer
#  72%|███████▏  | 72/100 [00:17<00:06,  4.55it/s]
# magnetisation_theta
# integer
#  73%|███████▎  | 73/100 [00:18<00:05,  4.65it/s]
# magnetisation_theta
# integer
#  74%|███████▍  | 74/100 [00:18<00:05,  4.71it/s]
# magnetisation_theta
# integer
#  75%|███████▌  | 75/100 [00:18<00:05,  4.77it/s]
# magnetisation_theta
# integer
# magnetisation_theta
#  76%|███████▌  | 76/100 [00:18<00:05,  4.76it/s]
# integer
# magnetisation_theta
#  78%|███████▊  | 78/100 [00:19<00:04,  4.85it/s]
# integer
# magnetisation_theta
# integer
#  79%|███████▉  | 79/100 [00:19<00:04,  4.83it/s]
# magnetisation_theta
# integer
#  80%|████████  | 80/100 [00:19<00:04,  4.80it/s]
# magnetisation_theta
# integer
#  81%|████████  | 81/100 [00:19<00:03,  4.77it/s]
# magnetisation_theta
# integer
#  82%|████████▏ | 82/100 [00:19<00:03,  4.69it/s]
# magnetisation_theta
# integer
#  83%|████████▎ | 83/100 [00:20<00:03,  4.70it/s]
# magnetisation_theta
# integer
#  84%|████████▍ | 84/100 [00:20<00:03,  4.58it/s]
# magnetisation_theta
# integer
#  85%|████████▌ | 85/100 [00:20<00:03,  4.58it/s]
# magnetisation_theta
# integer
#  86%|████████▌ | 86/100 [00:20<00:03,  4.58it/s]
# magnetisation_theta
# integer
#  87%|████████▋ | 87/100 [00:20<00:02,  4.65it/s]
# magnetisation_theta
# integer
#  88%|████████▊ | 88/100 [00:21<00:02,  4.71it/s]
# magnetisation_theta
# integer
# magnetisation_theta
#  89%|████████▉ | 89/100 [00:21<00:02,  4.28it/s]
# integer
# magnetisation_theta
#  90%|█████████ | 90/100 [00:21<00:02,  3.89it/s]
# integer
# magnetisation_theta
#  91%|█████████ | 91/100 [00:22<00:02,  3.90it/s]
# integer
# magnetisation_theta
#  92%|█████████▏| 92/100 [00:22<00:02,  3.60it/s]
# integer
# magnetisation_theta
#  93%|█████████▎| 93/100 [00:22<00:02,  3.50it/s]
# integer
# magnetisation_theta
#  94%|█████████▍| 94/100 [00:22<00:01,  3.49it/s]
# integer
# magnetisation_theta
#  95%|█████████▌| 95/100 [00:23<00:01,  3.71it/s]
# integer
# magnetisation_theta
#  96%|█████████▌| 96/100 [00:23<00:01,  3.79it/s]
# integer
# magnetisation_theta
#  97%|█████████▋| 97/100 [00:23<00:00,  3.97it/s]
# integer
# magnetisation_theta
#  98%|█████████▊| 98/100 [00:23<00:00,  4.17it/s]
# integer
# magnetisation_theta
#  99%|█████████▉| 99/100 [00:24<00:00,  4.36it/s]
# integer
# magnetisation_theta
# 100%|██████████| 100/100 [00:24<00:00,  4.11it/s]

# %%
M,img,MagnetisationTheta,MagnetisationPhi,NVtheta,NVPhi = G_cnn(img_input.to(device),(mask_t.to(device)),IntegerOnly=True)
MagnetisationMap = img[0,0,:,:].detach().cpu().numpy()
#BayesianSTD = stds[0,0,:,:].detach().cpu().numpy()
ReconstructedBnv=bnv_cnn[2][0,0,:,:].detach().cpu().numpy()

# %%
MagnetisationTheta
# Out:
# tensor([[-0.1076]], grad_fn=<AddmmBackward0>)

# %%
fig = plt.figure()
# to change size of subplot's
# set height of each subplot as 8
fig.set_figheight(6)

# set width of each subplot as 8
fig.set_figwidth(18)

plt.subplot(1,4,1)
plt.imshow(PROP.MagneticFieldExtended, cmap="bwr")
plt.colorbar(fraction=0.046, pad=0.04,label="$B (G)$")
plt.clim([-200,200])
plt.title('Magnetic Field')

plt.subplot(1,4,2)
plt.imshow(ReconstructedBnv,cmap='bwr')
plt.colorbar(fraction=0.046, pad=0.04)
plt.clim([-200,200])
plt.title('reconstructed magneticfield')

plt.subplot(1,4,3)
plt.imshow(MagnetisationMap,cmap='PuOr')
plt.colorbar(fraction=0.046, pad=0.04,label="$Mz (Ubnm^2)$")
plt.clim([-100,100])
plt.title('Reconstructed magnetisation')
# Out:
# Text(0.5, 1.0, 'Reconstructed magnetisation')
